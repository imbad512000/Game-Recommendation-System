# %% [markdown]
# ### Recommendation system
#
# Hello everyone, I present a small recommendation system for this dataset. If someone still looks at this notebook and finds mistakes, please point me to them. Thank you

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import hstack

# %%
# Importing the files you want
steam_csv = pd.read_csv('steam.csv')
descr_csv = pd.read_csv('steam_description_data.csv')

# %%
# Total size
steam_csv.shape
# Out:
# (27075, 18)

# %% [markdown]
# The recommendation system will be based on the game name, developer, genre, tags and description. The dataframe contains 27,000 games. Since not all games can meet their tags or players' expectations, I decided to remove games with a difference between positive and negative ratings less than 10. One of the options might not be to completely remove these games from the dataframe, but to remove these games from the recommendations, which will allow you to search games similar to them, but with a positive rating. But the first method allows you to reduce the dataframe, so I could not resist deleting. Games without English translation have been removed, as recommendations for such games are likely to be incorrect

# %%
# Combining dataframes
steam_csv = steam_csv.rename(columns={'appid':'steam_appid'})
united_df = steam_csv.merge(descr_csv, on='steam_appid')

# Removing unused columns
united_df = united_df.drop(['release_date',
                            'platforms',
                            'required_age',
                            'achievements',
                            'average_playtime',
                            'median_playtime',
                            'owners',
                            'price',
                            'about_the_game',
                            'categories',
                            'publisher',
                            'detailed_description'],1)

# Creating a rating difference
united_df['rating_difference'] = united_df['positive_ratings'] - united_df['negative_ratings']

# Removing games with negative and very low ratings
united_df = united_df.drop(united_df[united_df['rating_difference'] <= 10].index).reset_index(drop=True)

# Removing games without English translation
united_df = united_df.drop(united_df[united_df['english'] == 0].index).reset_index(drop=True)

# %%
# Total size 
united_df.to_csv('United_df.csv',index=False)

# %%
united_df
# Out:
#        steam_appid                           name  english  \
# 0               10                 Counter-Strike        1
# 1               20          Team Fortress Classic        1
# 2               30                  Day of Defeat        1
# 3               40             Deathmatch Classic        1
# 4               50      Half-Life: Opposing Force        1
# ...            ...                            ...      ...
# 13834      1058430             A Legionary's Life        1
# 13835      1059090  The Underground Watcher/地下监察员        1
# 13836      1059280                  The Renovator        1
# 13837      1062670                 Blacksmith Run        1
# 13838      1064580                 CaptainMarlene        1
#
#                 developer                        genres  \
# 0                   Valve                        Action
# 1                   Valve                        Action
# 2                   Valve                        Action
# 3                   Valve                        Action
# 4        Gearbox Software                        Action
# ...                   ...                           ...
# 13834  Alessandro Roberti        Indie;RPG;Early Access
# 13835           Yima VLG.                  Action;Indie
# 13836          mirzagame5                         Indie
# 13837     Skull Box Games                         Indie
# 13838              Dnovel  Adventure;Indie;Early Access
#
#                       steamspy_tags  positive_ratings  negative_ratings  \
# 0            Action;FPS;Multiplayer            124534              3339
# 1            Action;FPS;Multiplayer              3318               633
# 2      FPS;World War II;Multiplayer              3416               398
# 3            Action;FPS;Multiplayer              1273               267
# 4                 FPS;Action;Sci-fi              5250               288
# ...                             ...               ...               ...
# 13834        Early Access;RPG;Indie                22                 8
# 13835   Action;Indie;Pixel Graphics                13                 1
# 13836        Indie;Horror;Adventure                25                 7
# 13837                         Indie                13                 0
# 13838  Early Access;Indie;Adventure                13                 0
#
#                                        short_description  rating_difference
# 0      Play the world's number 1 online action game. ...             121195
# 1      One of the most popular online action games of...               2685
# 2      Enlist in an intense brand of Axis vs. Allied ...               3018
# 3      Enjoy fast-paced multiplayer gaming with Death...               1006
# 4      Return to the Black Mesa Research Facility as ...               4962
# ...                                                  ...                ...
# 13834  A Legionary's Life lets you play as a Roman so...                 14
# 13835  This is a story about a girl working undergrou...                 12
# 13836  In this game you’re an experienced restorer cu...                 18
# 13837  Go with the brave blacksmith on his journey fo...                 13
# 13838  In the game CaptainMarlene, you control the sp...                 13
#
# [13839 rows x 10 columns]

# %% [markdown]
# Several interesting graphs

# %%
# Selecting the required part of the dataframe
dev_head = united_df['developer'].value_counts().head(10)

# Create a figure
fig1, ax1 = plt.subplots(figsize=(10,4))

# Building a graph from a series
dev_head.plot(kind='barh', color='lightcoral', ax=ax1)

# Changing the order of lines on the chart
plt.gca().invert_yaxis()

# Sign the axes and give the name
plt.title('Number of games per developer')
plt.xlabel('Number of games')
plt.ylabel('Developer')

# Draw vertical lines
plt.grid(axis='x')
ax1.set_axisbelow(True)
plt.show()

# %%
# Selecting the required part of the dataframe
group_sum = united_df.groupby('developer')['rating_difference'].sum()

# Divide values to improve display
head_mill = group_sum.sort_values(ascending=False).head(10)/1000

fig2, ax2 = plt.subplots(figsize=(10,4))

head_mill.plot(kind='barh', color='lightcoral', ax=ax2)

plt.gca().invert_yaxis()

plt.title('The sum of the difference in ratings per developer')
plt.xlabel('The sum of the difference in ratings, thousand')
plt.ylabel('Developer')

plt.grid(axis='x')
ax2.set_axisbelow(True)
plt.show()

# %%
# Repeat all the same
diff_sort = united_df.sort_values(by='rating_difference', ascending=False).head(10)
diff_sort['rating_difference'] = diff_sort['rating_difference']/1000

fig3, ax3 = plt.subplots(figsize=(10,4))

diff_sort.plot(kind='barh', y='rating_difference', x='name', color='lightcoral', ax=ax3)

plt.gca().invert_yaxis()

plt.title('Difference in ratings per game')
plt.xlabel('Difference in ratings, thousand')
plt.ylabel('Game')

plt.grid(axis='x')
ax3.set_axisbelow(True)
plt.show()

# %% [markdown]
# Convenience functions

# %%
# Separating tags with a space
def globalization(strok:str):
    return strok.replace(';', ' ')

# Removing duplicate tags
def del_rep(strok:str):
    spl_strok = strok.split()
    return ' '.join(sorted(set(spl_strok), key=spl_strok.index))

# Converting to lower case
def to_low(strok:str):
    return strok.lower()

# %% [markdown]
# You need to combine the values from the columns name, developer, genres, steamspy_tags into one. All letters are converted to lower case. Sometimes the values of the genres and steamspy_tags columns are the same, so you need to remove duplicates

# %%
# Separating tags with a space
united_df['genres'] = united_df['genres'].apply(globalization)
united_df['steamspy_tags'] = united_df['steamspy_tags'].apply(globalization)

# Combining genres and tags
united_df['genres&tags'] = united_df['genres'] + ' ' + united_df['steamspy_tags']

# Removing duplicate tags
united_df['genres&tags'] = united_df['genres&tags'].apply(del_rep)

# Convert strings to lowercase and concatenate into one column
cols = ['developer', 'genres&tags']
united_df['alls'] = united_df['name'].copy().apply(to_low)
for i in cols:
    united_df['alls'] += ' ' + united_df[i].apply(to_low)

# %%
# How it looks
united_df['alls']
# Out:
# 0              counter-strike valve action fps multiplayer
# 1        team fortress classic valve action fps multipl...
# 2        day of defeat valve action fps world war ii mu...
# 3          deathmatch classic valve action fps multiplayer
# 4        half-life: opposing force gearbox software act...
#                                ...
# 13834    a legionary's life alessandro roberti indie rp...
# 13835    the underground watcher/地下监察员 yima vlg. action...
# 13836      the renovator mirzagame5 indie horror adventure
# 13837                 blacksmith run skull box games indie
# 13838    captainmarlene dnovel adventure indie early ac...
# Name: alls, Length: 13839, dtype: object

# %% [markdown]
# For tag-like strings, it is better to use the CountVectorizer. He convert a collection of text documents to a matrix of token counts. By calculating the cosine similarity for each game, we can determine how similar they are.

# %%
# Convert a collection of text documents to a matrix of token counts
count_vec = CountVectorizer(stop_words='english')
count_matrix = count_vec.fit_transform(united_df['alls'])

# Compute cosine similarity
cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %% [markdown]
# Converting short description to vectors. For text-like strings, it is better to use the TfidfVectorizer. He performs the TF-IDF transformation from a provided matrix of counts. Using hstack, you can combine matrices and calculate the cosine convergence so that when making recommendations, you can also take into account the description of the game

# %%
# Convert a collection of raw documents to a matrix of TF-IDF features
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(united_df['short_description'])

# Stack sparse matrices horizontally
st = hstack([count_matrix, tfidf_matrix])

# Compute cosine similarity
cosine_sim2 = cosine_similarity(st, st)

# %% [markdown]
# This function makes 10 recommendations based on the calculated cosine similarity. In this case, there are two options: recommendations based on title, developer and tags, and the same recommendations, but using a short description

# %%
# The main function that makes recommendations
def get_rec(nam:str, cosine):
#     Determine the index
    ind = united_df[united_df['name'] == nam].index.to_list()[0]
    
#     Obtaining cosine convergence by index
    cos_scor = list(enumerate(cosine[ind]))
    
#     Getting the most suitable games
    cos_scor = sorted(cos_scor, key=lambda x: x[1], reverse=True)
    cos_scor = cos_scor[1:11]
    ten_ind = [i[0] for i in cos_scor]
    return united_df['name'].iloc[ten_ind]

# this loop logic written in a manav's notebook & phone pic in my iphone.

# %%
ind = united_df[united_df['name'] == "A Legionary's Life"].index.to_list()[0]
    
#     Obtaining cosine convergence by index
cos_scor = list(enumerate(cosine_sim2[ind]))
    
#     Getting the most suitable games
cos_scor = sorted(cos_scor, key=lambda x: x[1], reverse=True)
cos_scor = cos_scor[1:11]
ten_ind = [i[0] for i in cos_scor]
cand_s = united_df['name'].iloc[ten_ind]
df = pd.DataFrame()
new_hr = df.assign(candidates = cand_s)
new_hr.reset_index(drop=True, inplace = True)
new_hr.index = new_hr.index + 1
new_hr
# Out:
#             candidates
# 1   This Merchant Life
# 2             Keplerth
# 3          Magic Tower
# 4             NEOVERSE
# 5                  GoK
# 6        LandTraveller
# 7               Egress
# 8     Hobo: Tough Life
# 9           FreeHolder
# 10      Long Gone Days

# %%
cos_scor = list(enumerate(cosine_sim2[118]))
cos_scor
# Out:
# [(0, 0.09759000729485331),
#  (1, 0.09128709291752768),
#  (2, 0.2449489742783178),
#  (3, 0.0975900072948533),
#  (4, 0.0778498944161523),
#  (5, 0.10540925533894598),
#  (6, 0.0975900072948533),
#  (7, 0.08606629658238703),
#  (8, 0.07784989441615228),
#  (9, 0.09128709291752767),
#  (10, 0.09128709291752768),
#  (11, 0.08606629658238701),
#  (12, 0.23354968324845687),
#  (13, 0.09128709291752767),
#  (14, 0.08606629658238703),
#  (15, 0.08606629658238704),
#  (16, 0.08606629658238704),
#  (17, 0.09759000729485331),
#  (18, 0.08606629658238704),
#  (19, 0.08606629658238704),
#  (20, 0.09372211264263969),
#  (21, 0.09128709291752768),
#  (22, 0.09128709291752767),
#  (23, 0.09128709291752767),
#  (24, 0.09128709291752767),
#  (25, 0.06666666666666665),
#  (26, 0.0),
#  (27, 0.2148344622118299),
#  (28, 0.08956746555532956),
#  (29, 0.08606629658238701),
#  (30, 0.0014681308678573936),
#  (31, 0.0),
#  (32, 0.0),
#  (33, 0.0),
#  (34, 0.0028966022061558305),
#  (35, 0.0017615926599111082),
#  (36, 0.0),
#  (37, 0.0),
#  (38, 0.0),
#  (39, 0.0),
#  (40, 0.09264523352975156),
#  (41, 0.0),
#  (42, 0.0020597391838724586),
#  (43, 0.31139957766460913),
#  (44, 0.1721325931647741),
#  (45, 0.08606629658238701),
#  (46, 0.08606629658238704),
#  (47, 0.09128709291752767),
#  (48, 0.09128709291752767),
#  (49, 0.09128709291752767),
#  (50, 0.09128709291752767),
#  (51, 0.09759000729485331),
#  (52, 0.09128709291752768),
#  (53, 0.07784989441615227),
#  (54, 0.07453559924999299),
#  (55, 0.0816496580927726),
#  (56, 0.09339877019848258),
#  (57, 0.0816496580927726),
#  (58, 0.16614566812673462),
#  (59, 0.17213259316477408),
#  (60, 0.09128709291752768),
#  (61, 0.0975900072948533),
#  (62, 0.0887183859722385),
#  (63, 0.14322297480788657),
#  (64, 0.39036002917941326),
#  (65, 0.25819888974716104),
#  (66, 0.23354968324845687),
#  (67, 0.223606797749979),
#  (68, 0.14907119849998596),
#  (69, 0.09128709291752767),
#  (70, 0.08606629658238701),
#  (71, 0.00147451566951821),
#  (72, 0.0015681707101239707),
#  (73, 0.07784989441615227),
#  (74, 0.0),
#  (75, 0.0),
#  (76, 0.0),
#  (77, 0.0),
#  (78, 0.0029386066025184235),
#  (79, 0.0),
#  (80, 0.0),
#  (81, 0.10540925533894598),
#  (82, 0.0024041036966012583),
#  (83, 0.1389460882610847),
#  (84, 0.0778498944161523),
#  (85, 0.0),
#  (86, 0.09128709291752767),
#  (87, 0.0),
#  (88, 0.08606629658238703),
#  (89, 0.0),
#  (90, 0.0023479510069077834),
#  (91, 0.0),
#  (92, 0.1632993161855452),
#  (93, 0.0),
#  (94, 0.0),
#  (95, 0.0),
#  (96, 0.0),
#  (97, 0.0),
#  (98, 0.09128709291752767),
#  (99, 0.08606629658238701),
#  (100, 0.07453559924999299),
#  (101, 0.0),
#  (102, 0.07453559924999299),
#  (103, 0.0816496580927726),
#  (104, 0.09128709291752767),
#  (105, 0.09128709291752767),
#  (106, 0.08744157621031207),
#  (107, 0.0),
#  (108, 0.0),
#  (109, 0.29814239699997197),
#  (110, 0.0),
#  (111, 0.0),
#  (112, 0.006876405247604061),
#  (113, 0.0975900072948533),
#  (114, 0.09128709291752767),
#  (115, 0.18257418583505533),
#  (116, 0.0),
#  (117, 0.16329931618554522),
#  (118, 0.9999999999999997),
#  (119, 0.09128709291752768),
#  (120, 0.08606629658238704),
#  (121, 0.20701966780270625),
#  (122, 0.06262242910851495),
#  (123, 0.0),
#  (124, 0.0),
#  (125, 0.18257418583505533),
#  (126, 0.0),
#  (127, 0.0),
#  (128, 0.0),
#  (129, 0.408248290463863),
#  (130, 0.34426518632954806),
#  (131, 0.3265986323710904),
#  (132, 0.3265986323710904),
#  (133, 0.3113995776646092),
#  (134, 0.0),
#  (135, 0.08149062403256438),
#  (136, 0.06900655593423541),
#  (137, 0.005510531103788376),
#  (138, 0.05504818825631802),
#  (139, 0.05504818825631801),
#  (140, 0.0),
#  (141, 0.06565147007962868),
#  (142, 0.08606629658238704),
#  (143, 0.0816496580927726),
#  (144, 0.09128709291752767),
#  (145, 0.0),
#  (146, 0.0),
#  (147, 0.0),
#  (148, 0.0816496580927726),
#  (149, 0.07784989441615231),
#  (150, 0.15569978883230462),
#  (151, 0.07784989441615228),
#  (152, 0.08606629658238701),
#  (153, 0.0),
#  (154, 0.0816496580927726),
#  (155, 0.08164965809277258),
#  (156, 0.08606629658238704),
#  (157, 0.09443798372340531),
#  (158, 0.0816496580927726),
#  (159, 0.08606629658238703),
#  (160, 0.08606629658238701),
#  (161, 0.08606629658238701),
#  (162, 0.24494897427831774),
#  (163, 0.3442651863295481),
#  (164, 0.08606629658238703),
#  (165, 0.2275024191705929),
#  (166, 0.0816496580927726),
#  (167, 0.17213259316477406),
#  (168, 0.0816496580927726),
#  (169, 0.09128709291752767),
#  (170, 0.08606629658238704),
#  (171, 0.07784989441615231),
#  (172, 0.0),
#  (173, 0.0),
#  (174, 0.00130810672834393),
#  (175, 0.18257418583505536),
#  (176, 0.14322297480788654),
#  (177, 0.28644594961577313),
#  (178, 0.0),
#  (179, 0.0),
#  (180, 0.0),
#  (181, 0.0),
#  (182, 0.0),
#  (183, 0.0),
#  (184, 0.15112112071562941),
#  (185, 0.273861278752583),
#  (186, 0.07784989441615228),
#  (187, 0.07161148740394328),
#  (188, 0.0778498944161523),
#  (189, 0.08164965809277261),
#  (190, 0.23354968324845693),
#  (191, 0.32659863237109044),
#  (192, 0.0),
#  (193, 0.06900655593423541),
#  (194, 0.002308019658363118),
#  (195, 0.13801311186847084),
#  (196, 0.0),
#  (197, 0.06900655593423542),
#  (198, 0.0),
#  (199, 0.06900655593423541),
#  (200, 0.09128709291752768),
#  (201, 0.08164965809277261),
#  (202, 0.0),
#  (203, 0.002806638070197284),
#  (204, 0.09128709291752767),
#  (205, 0.08164965809277258),
#  (206, 0.07784989441615227),
#  (207, 0.0778498944161523),
#  (208, 0.09759000729485331),
#  (209, 0.09128709291752768),
#  (210, 0.0816496580927726),
#  (211, 0.09128709291752768),
#  (212, 0.27386127875258304),
#  (213, 0.0),
#  (214, 0.08164965809277258),
#  (215, 0.0),
#  (216, 0.0),
#  (217, 0.0),
#  (218, 0.08606629658238704),
#  (219, 0.34426518632954817),
#  (220, 0.0),
#  (221, 0.08164965809277262),
#  (222, 0.09128709291752768),
#  (223, 0.0),
#  (224, 0.0778498944161523),
#  (225, 0.06900655593423542),
#  (226, 0.07784989441615231),
#  (227, 0.0),
#  (228, 0.33333333333333326),
#  (229, 0.0),
#  (230, 0.0),
#  (231, 0.09128709291752767),
#  (232, 0.0),
#  (233, 0.367820035632301),
#  (234, 0.07784989441615231),
#  (235, 0.08606629658238701),
#  (236, 0.0),
#  (237, 0.0858795913888056),
#  (238, 0.0),
#  (239, 0.0816496580927726),
#  (240, 0.0),
#  (241, 0.0),
#  (242, 0.0),
#  (243, 0.07453559924999299),
#  (244, 0.09594368089175692),
#  (245, 0.0),
#  (246, 0.14907119849998599),
#  (247, 0.1556997888323046),
#  (248, 0.2581988897471611),
#  (249, 0.0),
#  (250, 0.10540925533894598),
#  (251, 0.0),
#  (252, 0.0816496580927726),
#  (253, 0.2369395511036369),
#  (254, 0.0),
#  (255, 0.3113995776646092),
#  (256, 0.29946995675445565),
#  (257, 0.29814239699997197),
#  (258, 0.09128709291752767),
#  (259, 0.09128709291752767),
#  (260, 0.06643704943938789),
#  (261, 0.3265986323710904),
#  (262, 0.32659863237109044),
#  (263, 0.31521590237167263),
#  (264, 0.2581988897471611),
#  (265, 0.2760262237369417),
#  (266, 0.07453559924999299),
#  (267, 0.17565022530412583),
#  (268, 0.09251804185220927),
#  (269, 0.0),
#  (270, 0.0),
#  (271, 0.0),
#  (272, 0.002367560512358093),
#  (273, 0.0014410514918734973),
#  (274, 0.0),
#  (275, 0.08606629658238701),
#  (276, 0.0),
#  (277, 0.09128709291752768),
#  (278, 0.14907119849998599),
#  (279, 0.18257418583505536),
#  (280, 0.07784989441615231),
#  (281, 0.0816496580927726),
#  (282, 0.0),
#  (283, 0.0816496580927726),
#  (284, 0.08606629658238701),
#  (285, 0.08606629658238701),
#  (286, 0.07161148740394327),
#  (287, 0.15569978883230454),
#  (288, 0.09434023860099869),
#  (289, 0.09128709291752767),
#  (290, 0.0975900072948533),
#  (291, 0.08606629658238704),
#  (292, 0.0816496580927726),
#  (293, 0.08606629658238701),
#  (294, 0.07453559924999296),
#  (295, 0.08860671276304005),
#  (296, 0.07161148740394328),
#  (297, 0.06900655593423542),
#  (298, 0.29814239699997197),
#  (299, 0.0816496580927726),
#  (300, 0.09128709291752768),
#  (301, 0.0),
#  (302, 0.0),
#  (303, 0.2160344400039843),
#  (304, 0.14907119849998599),
#  (305, 0.1632993161855452),
#  (306, 0.13801311186847084),
#  (307, 0.0975900072948533),
#  (308, 0.07784989441615231),
#  (309, 0.14907119849998593),
#  (310, 0.0),
#  (311, 0.0),
#  (312, 0.22360679774997888),
#  (313, 0.0778498944161523),
#  (314, 0.2449489742783178),
#  (315, 0.07453559924999299),
#  (316, 0.07453559924999298),
#  (317, 0.0),
#  (318, 0.0),
#  (319, 0.0),
#  (320, 0.07784989441615228),
#  (321, 0.07161148740394328),
#  (322, 0.0),
#  (323, 0.0),
#  (324, 0.0),
#  (325, 0.0),
#  (326, 0.0),
#  (327, 0.0),
#  (328, 0.0021192006071267806),
#  (329, 0.0),
#  (330, 0.0),
#  (331, 0.0),
#  (332, 0.0),
#  (333, 0.09998939070929058),
#  (334, 0.0),
#  (335, 0.09128709291752768),
#  (336, 0.08726119883764313),
#  (337, 0.10035565762414943),
#  (338, 0.0),
#  (339, 0.0816496580927726),
#  (340, 0.0816496580927726),
#  (341, 0.0),
#  (342, 0.0),
#  (343, 0.09997242633371055),
#  (344, 0.09892225256466503),
#  (345, 0.09128709291752768),
#  (346, 0.29849787202993894),
#  (347, 0.09128709291752768),
#  (348, 0.2981423969999719),
#  (349, 0.23354968324845685),
#  (350, 0.08606629658238704),
#  (351, 0.16613733675298142),
#  (352, 0.0816496580927726),
#  (353, 0.0),
#  (354, 0.06472634067750403),
#  (355, 0.07453559924999298),
#  (356, 0.08606629658238703),
#  (357, 0.0816496580927726),
#  (358, 0.08606629658238704),
#  (359, 0.08606629658238703),
#  (360, 0.19518001458970663),
#  (361, 0.17213259316477406),
#  (362, 0.19518001458970663),
#  (363, 0.0816496580927726),
#  (364, 0.0),
#  (365, 0.0),
#  (366, 0.0018206951954046454),
#  (367, 0.002810287018785046),
#  (368, 0.0),
#  (369, 0.09128709291752768),
#  (370, 0.08606629658238704),
#  (371, 0.0),
#  (372, 0.09128709291752767),
#  (373, 0.09128709291752767),
#  (374, 0.22467472180788547),
#  (375, 0.07161148740394328),
#  (376, 0.3265986323710904),
#  (377, 0.09128709291752768),
#  (378, 0.8203793442755418),
#  (379, 0.09375683579713708),
#  (380, 0.14907119849998599),
#  (381, 0.09128709291752767),
#  (382, 0.0),
#  (383, 0.10540925533894598),
#  (384, 0.0975900072948533),
#  (385, 0.09128709291752767),
#  (386, 0.13801311186847084),
#  (387, 0.07453559924999296),
#  (388, 0.0778498944161523),
#  (389, 0.08164965809277261),
#  (390, 0.08164965809277261),
#  (391, 0.0975900072948533),
#  (392, 0.09759000729485331),
#  (393, 0.07453559924999299),
#  (394, 0.0),
#  (395, 0.0),
#  (396, 0.09128709291752767),
#  (397, 0.09759000729485331),
#  (398, 0.09128709291752767),
#  (399, 0.08606629658238703),
#  (400, 0.3265986323710904),
#  (401, 0.0),
#  (402, 0.09128709291752768),
#  (403, 0.18257418583505533),
#  (404, 0.3265986323710904),
#  (405, 0.06666666666666667),
#  (406, 0.14907119849998596),
#  (407, 0.08280369175549207),
#  (408, 0.09128709291752767),
#  (409, 0.0816496580927726),
#  (410, 0.5715476066494082),
#  (411, 0.09759000729485327),
#  (412, 0.37573457465108956),
#  (413, 0.3757345746510896),
#  (414, 0.08606629658238704),
#  (415, 0.5353167463717762),
#  (416, 0.5217491947499509),
#  (417, 0.08606629658238703),
#  (418, 0.08606629658238706),
#  (419, 0.0),
#  (420, 0.0816496580927726),
#  (421, 0.08606629658238703),
#  (422, 0.08606629658238704),
#  (423, 0.0),
#  (424, 0.08606629658238701),
#  (425, 0.0),
#  (426, 0.0),
#  (427, 0.0),
#  (428, 0.08606629658238704),
#  (429, 0.0),
#  (430, 0.07161148740394328),
#  (431, 0.09128709291752767),
#  (432, 0.0),
#  (433, 0.0),
#  (434, 0.19999999999999996),
#  (435, 0.09128709291752767),
#  (436, 0.08372783695757978),
#  (437, 0.0),
#  (438, 0.0778498944161523),
#  (439, 0.0),
#  (440, 0.08940944434606414),
#  (441, 0.23561726895013319),
#  (442, 0.0),
#  (443, 0.0),
#  (444, 0.0),
#  (445, 0.0),
#  (446, 0.22360679774997894),
#  (447, 0.0),
#  (448, 0.09128709291752768),
#  (449, 0.08606629658238701),
#  (450, 0.1007071563477185),
#  (451, 0.08606629658238703),
#  (452, 0.0),
#  (453, 0.09128709291752767),
#  (454, 0.08606629658238704),
#  (455, 0.09128709291752767),
#  (456, 0.0),
#  (457, 0.0),
#  (458, 0.08748694153456252),
#  (459, 0.14907119849998596),
#  (460, 0.08164965809277258),
#  (461, 0.0),
#  (462, 0.0),
#  (463, 0.0),
#  (464, 0.08606629658238703),
#  (465, 0.0),
#  (466, 0.0),
#  (467, 0.0),
#  (468, 0.0),
#  (469, 0.08164965809277261),
#  (470, 0.0),
#  (471, 0.0027669748414893844),
#  (472, 0.0),
#  (473, 0.07784989441615228),
#  (474, 0.1951800145897066),
#  (475, 0.0),
#  (476, 0.0),
#  (477, 0.0),
#  (478, 0.1749928970497819),
#  (479, 0.09030410237319043),
#  (480, 0.0),
#  (481, 0.0),
#  (482, 0.0),
#  (483, 0.007029622620149537),
#  (484, 0.0),
#  (485, 0.0),
#  (486, 0.0),
#  (487, 0.0),
#  (488, 0.0778498944161523),
#  (489, 0.0),
#  (490, 0.0),
#  (491, 0.0),
#  (492, 0.0),
#  (493, 0.0),
#  (494, 0.0),
#  (495, 0.0),
#  (496, 0.0),
#  (497, 0.0816496580927726),
#  (498, 0.0),
#  (499, 0.0716114874039433),
#  (500, 0.0043453708176419996),
#  (501, 0.0),
#  (502, 0.059234887775909226),
#  (503, 0.06262242910851494),
#  (504, 0.06454972243679029),
#  (505, 0.06900655593423542),
#  (506, 0.0),
#  (507, 0.060655851658022945),
#  (508, 0.0),
#  (509, 0.06666666666666665),
#  (510, 0.0),
#  (511, 0.0),
#  (512, 0.06262242910851495),
#  (513, 0.052704627669472974),
#  (514, 0.09759000729485331),
#  (515, 0.0975900072948533),
#  (516, 0.09759000729485331),
#  (517, 0.08606629658238704),
#  (518, 0.07784989441615231),
#  (519, 0.0975900072948533),
#  (520, 0.08606629658238701),
#  (521, 0.07784989441615231),
#  (522, 0.0),
#  (523, 0.0),
#  (524, 0.0),
#  (525, 0.0),
#  (526, 0.10540925533894598),
#  (527, 0.0),
#  (528, 0.0816496580927726),
#  (529, 0.0),
#  (530, 0.15866447265027628),
#  (531, 0.17450646678082557),
#  (532, 0.17213259316477406),
#  (533, 0.17213259316477408),
#  (534, 0.17213259316477406),
#  (535, 0.31305228396635376),
#  (536, 0.0816496580927726),
#  (537, 0.09128709291752767),
#  (538, 0.09672477611762113),
#  (539, 0.0),
#  (540, 0.08606629658238703),
#  (541, 0.0),
#  (542, 0.0),
#  (543, 0.3651483716701107),
#  (544, 0.18257418583505533),
#  (545, 0.0),
#  (546, 0.07161148740394327),
#  (547, 0.0),
#  (548, 0.09351625970268836),
#  (549, 0.09128709291752765),
#  (550, 0.08164965809277258),
#  (551, 0.0),
#  (552, 0.08870931024793582),
#  (553, 0.18257418583505536),
#  (554, 0.0),
#  (555, 0.0),
#  (556, 0.0816496580927726),
#  (557, 0.0),
#  (558, 0.14907119849998599),
#  (559, 0.003015925387738411),
#  (560, 0.09128709291752767),
#  (561, 0.14907119849998599),
#  (562, 0.0778498944161523),
#  (563, 0.07784989441615228),
#  (564, 0.0),
#  (565, 0.09128709291752768),
#  (566, 0.0019175802413608468),
#  (567, 0.0816496580927726),
#  (568, 0.12171612389003694),
#  (569, 0.0),
#  (570, 0.09759000729485331),
#  (571, 0.0975900072948533),
#  (572, 0.18257418583505533),
#  (573, 0.09128709291752767),
#  (574, 0.0),
#  (575, 0.07784989441615231),
#  (576, 0.0816496580927726),
#  (577, 0.0),
#  (578, 0.07453559924999299),
#  (579, 0.0024699587821069347),
#  (580, 0.0),
#  (581, 0.09070093641131073),
#  (582, 0.08371061832088039),
#  (583, 0.0),
#  (584, 0.21081851067789195),
#  (585, 0.0),
#  (586, 0.0),
#  (587, 0.0),
#  (588, 0.0),
#  (589, 0.09128709291752767),
#  (590, 0.0),
#  (591, 0.0),
#  (592, 0.0),
#  (593, 0.0032415103620914328),
#  (594, 0.08606629658238703),
#  (595, 0.0),
#  (596, 0.0),
#  (597, 0.0),
#  (598, 0.0),
#  (599, 0.0),
#  (600, 0.0),
#  (601, 0.0),
#  (602, 0.0),
#  (603, 0.3450327796711771),
#  (604, 0.32274861218395146),
#  (605, 0.23354968324845693),
#  (606, 0.08606629658238701),
#  (607, 0.09128709291752768),
#  (608, 0.0975900072948533),
#  (609, 0.09128709291752767),
#  (610, 0.09128709291752768),
#  (611, 0.0),
#  (612, 0.0),
#  (613, 0.10540925533894598),
#  (614, 0.06900655593423542),
#  (615, 0.0),
#  (616, 0.0816496580927726),
#  (617, 0.08606629658238701),
#  (618, 0.08606629658238701),
#  (619, 0.17213259316477403),
#  (620, 0.16329931618554516),
#  (621, 0.07784989441615231),
#  (622, 0.4303314829119352),
#  (623, 0.372677996249965),
#  (624, 0.0),
#  (625, 0.18257418583505533),
#  (626, 0.0941435594175411),
#  (627, 0.09254378241738645),
#  (628, 0.0),
#  (629, 0.0),
#  (630, 0.0975900072948533),
#  (631, 0.0),
#  (632, 0.09980467502738563),
#  (633, 0.0),
#  (634, 0.3651483716701106),
#  (635, 0.1632993161855452),
#  (636, 0.0),
#  (637, 0.0),
#  (638, 0.0),
#  (639, 0.10540925533894598),
#  (640, 0.3289022865695192),
#  (641, 0.0),
#  (642, 0.0),
#  (643, 0.0),
#  (644, 0.0),
#  (645, 0.0),
#  (646, 0.0),
#  (647, 0.0),
#  (648, 0.0),
#  (649, 0.09128709291752767),
#  (650, 0.08606629658238703),
#  (651, 0.09128709291752767),
#  (652, 0.0975900072948533),
#  (653, 0.09128709291752767),
#  (654, 0.18257418583505533),
#  (655, 0.8445616699693174),
#  (656, 0.07784989441615228),
#  (657, 0.0),
#  (658, 0.17213259316477408),
#  (659, 0.0816496580927726),
#  (660, 0.0),
#  (661, 0.18257418583505533),
#  (662, 0.0),
#  (663, 0.0),
#  (664, 0.0),
#  (665, 0.09128709291752767),
#  (666, 0.09128709291752768),
#  (667, 0.09128709291752767),
#  (668, 0.0778498944161523),
#  (669, 0.21667199036215806),
#  (670, 0.0),
#  (671, 0.25819888974716104),
#  (672, 0.0),
#  (673, 0.0),
#  (674, 0.08779207806202016),
#  (675, 0.17213259316477406),
#  (676, 0.08606629658238704),
#  (677, 0.0),
#  (678, 0.0816496580927726),
#  (679, 0.0),
#  (680, 0.0),
#  (681, 0.06900655593423542),
#  (682, 0.0),
#  (683, 0.0020327361768021205),
#  (684, 0.0),
#  (685, 0.1632993161855452),
#  (686, 0.0),
#  (687, 0.0),
#  (688, 0.0),
#  (689, 0.17213259316477403),
#  (690, 0.07453559924999299),
#  (691, 0.3289013441420998),
#  (692, 0.08606629658238703),
#  (693, 0.0816496580927726),
#  (694, 0.31139957766460913),
#  (695, 0.0),
#  (696, 0.0938273406227036),
#  (697, 0.24950340246619573),
#  (698, 0.07784989441615231),
#  (699, 0.09128709291752768),
#  (700, 0.14907119849998599),
#  (701, 0.13801311186847082),
#  (702, 0.13801311186847082),
#  (703, 0.17213259316477406),
#  (704, 0.0816496580927726),
#  (705, 0.0),
#  (706, 0.0),
#  (707, 0.0),
#  (708, 0.2449489742783178),
#  (709, 0.07938252372810373),
#  (710, 0.09128709291752767),
#  (711, 0.0024465338129729362),
#  (712, 0.14322297480788657),
#  (713, 0.0),
#  (714, 0.0),
#  (715, 0.0816496580927726),
#  (716, 0.08606629658238703),
#  (717, 0.09128709291752767),
#  (718, 0.08606629658238701),
#  (719, 0.0778498944161523),
#  (720, 0.23354968324845685),
#  (721, 0.0),
#  (722, 0.0),
#  (723, 0.0),
#  (724, 0.3265986323710904),
#  (725, 0.0),
#  (726, 0.38924947208076144),
#  (727, 0.408248290463863),
#  (728, 0.0),
#  (729, 0.0),
#  (730, 0.07453559924999299),
#  (731, 0.13801311186847084),
#  (732, 0.07453559924999299),
#  (733, 0.0033268664726868627),
#  (734, 0.09128709291752767),
#  (735, 0.0),
#  (736, 0.29814239699997197),
#  (737, 0.07784989441615228),
#  (738, 0.0),
#  (739, 0.0),
#  (740, 0.001770578739436123),
#  (741, 0.0),
#  (742, 0.0),
#  (743, 0.0),
#  (744, 0.0),
#  (745, 0.08606629658238703),
#  (746, 0.09128709291752767),
#  (747, 0.0),
#  (748, 0.06900655593423542),
#  (749, 0.36514837167011066),
#  (750, 0.09410601182780763),
#  (751, 0.0),
#  (752, 0.15185106726066422),
#  (753, 0.0),
#  (754, 0.0),
#  (755, 0.0816496580927726),
#  (756, 0.0),
#  (757, 0.10540925533894595),
#  (758, 0.14907119849998599),
#  (759, 0.08606629658238704),
#  (760, 0.0),
#  (761, 0.0),
#  (762, 0.0),
#  (763, 0.0011480217475120064),
#  (764, 0.0),
#  (765, 0.0),
#  (766, 0.09128709291752767),
#  (767, 0.0),
#  (768, 0.0),
#  (769, 0.0),
#  (770, 0.09128709291752768),
#  (771, 0.07453559924999299),
#  (772, 0.16301967228253192),
#  (773, 0.006213084580131053),
#  (774, 0.08982081697192854),
#  (775, 0.08606629658238704),
#  (776, 0.09128709291752768),
#  (777, 0.0022392876301208634),
#  (778, 0.08606629658238701),
#  (779, 0.0),
#  (780, 0.0816496580927726),
#  (781, 0.0816496580927726),
#  (782, 0.0),
#  (783, 0.0),
#  (784, 0.0),
#  (785, 0.07784989441615228),
#  (786, 0.0816496580927726),
#  (787, 0.08606629658238704),
#  (788, 0.0019973814368882846),
#  (789, 0.0816496580927726),
#  (790, 0.0),
#  (791, 0.14322297480788654),
#  (792, 0.1333333333333333),
#  (793, 0.0),
#  (794, 0.003290696289639419),
#  (795, 0.0),
#  (796, 0.08164965809277261),
#  (797, 0.5163977794943222),
#  (798, 0.0),
#  (799, 0.27386127875258304),
#  (800, 0.0816496580927726),
#  (801, 0.08164965809277261),
#  (802, 0.14907119849998599),
#  (803, 0.08585010376391003),
#  (804, 0.0),
#  (805, 0.07453559924999298),
#  (806, 0.09128709291752768),
#  (807, 0.07784989441615231),
#  (808, 0.0),
#  (809, 0.0),
#  (810, 0.08606629658238704),
#  (811, 0.07453559924999299),
#  (812, 0.08606629658238704),
#  (813, 0.08266925089711237),
#  (814, 0.17213259316477408),
#  (815, 0.08606629658238701),
#  (816, 0.0),
#  (817, 0.0),
#  (818, 0.0),
#  (819, 0.0),
#  (820, 0.07784989441615228),
#  (821, 0.0975900072948533),
#  (822, 0.0),
#  (823, 0.09128709291752767),
#  (824, 0.0816496580927726),
#  (825, 0.0),
#  (826, 0.0),
#  (827, 0.38924947208076144),
#  (828, 0.09128709291752768),
#  (829, 0.0),
#  (830, 0.21483446221182984),
#  (831, 0.08606629658238701),
#  (832, 0.0),
#  (833, 0.0),
#  (834, 0.15569978883230456),
#  (835, 0.0),
#  (836, 0.0),
#  (837, 0.0),
#  (838, 0.0),
#  (839, 0.0),
#  (840, 0.0),
#  (841, 0.0),
#  (842, 0.0),
#  (843, 0.0),
#  (844, 0.07453559924999299),
#  (845, 0.19752761303016494),
#  (846, 0.07453559924999299),
#  (847, 0.1632993161855452),
#  (848, 0.0),
#  (849, 0.0),
#  (850, 0.34503277967117707),
#  (851, 0.08164965809277258),
#  (852, 0.0),
#  (853, 0.07453559924999298),
#  (854, 0.07784989441615228),
#  (855, 0.0778498944161523),
#  (856, 0.09128709291752767),
#  (857, 0.07453559924999299),
#  (858, 0.09128709291752767),
#  (859, 0.0),
#  (860, 0.08606629658238701),
#  (861, 0.0016249343619057694),
#  (862, 0.07161148740394328),
#  (863, 0.0),
#  (864, 0.09128709291752767),
#  (865, 0.0),
#  (866, 0.0),
#  (867, 0.0975900072948533),
#  (868, 0.10884939865014875),
#  (869, 0.06900655593423542),
#  (870, 0.0),
#  (871, 0.07784989441615231),
#  (872, 0.0),
#  (873, 0.0778498944161523),
#  (874, 0.13801311186847084),
#  (875, 0.09759000729485331),
#  (876, 0.0),
#  (877, 0.08606629658238703),
#  (878, 0.0),
#  (879, 0.0),
#  (880, 0.006206146324601506),
#  (881, 0.07453559924999299),
#  (882, 0.003527892456790698),
#  (883, 0.0),
#  (884, 0.21483446221182984),
#  (885, 0.07453559924999296),
#  (886, 0.18257418583505536),
#  (887, 0.09128709291752767),
#  (888, 0.07453559924999299),
#  (889, 0.09002152262057915),
#  (890, 0.08606629658238704),
#  (891, 0.0),
#  (892, 0.1333333333333333),
#  (893, 0.0),
#  (894, 0.0),
#  (895, 0.1632993161855452),
#  (896, 0.09128709291752767),
#  (897, 0.34503277967117707),
#  (898, 0.0842310304208499),
#  (899, 0.09128709291752768),
#  (900, 0.08606629658238701),
#  (901, 0.10540925533894598),
#  (902, 0.0),
#  (903, 0.0),
#  (904, 0.0816496580927726),
#  (905, 0.0),
#  (906, 0.223606797749979),
#  (907, 0.0),
#  (908, 0.08606629658238704),
#  (909, 0.08164965809277257),
#  (910, 0.0),
#  (911, 0.17213259316477406),
#  (912, 0.07784989441615228),
#  (913, 0.09128709291752767),
#  (914, 0.17213259316477403),
#  (915, 0.14322297480788657),
#  (916, 0.08606629658238701),
#  (917, 0.25819888974716104),
#  (918, 0.08606629658238704),
#  (919, 0.0816496580927726),
#  (920, 0.07784989441615231),
#  (921, 0.07784989441615228),
#  (922, 0.0816496580927726),
#  (923, 0.07063310533426737),
#  (924, 0.07453559924999299),
#  (925, 0.09128709291752767),
#  (926, 0.08164965809277261),
#  (927, 0.0),
#  (928, 0.17213259316477408),
#  (929, 0.07784989441615228),
#  (930, 0.0),
#  (931, 0.0),
#  (932, 0.08606629658238701),
#  (933, 0.09128709291752767),
#  (934, 0.22360679774997894),
#  (935, 0.1632993161855452),
#  (936, 0.0),
#  (937, 0.0816496580927726),
#  (938, 0.08606629658238703),
#  (939, 0.07784989441615231),
#  (940, 0.1333333333333333),
#  (941, 0.29814239699997186),
#  (942, 0.07920731130157123),
#  (943, 0.0816496580927726),
#  (944, 0.0),
#  (945, 0.07784989441615231),
#  (946, 0.3442651863295481),
#  (947, 0.3265986323710904),
#  (948, 0.3442651863295481),
#  (949, 0.07950720770125264),
#  (950, 0.0),
#  (951, 0.0),
#  (952, 0.07784989441615231),
#  (953, 0.18257418583505536),
#  (954, 0.0),
#  (955, 0.0),
#  (956, 0.18257418583505536),
#  (957, 0.0),
#  (958, 0.2961744388795462),
#  (959, 0.14907119849998593),
#  (960, 0.0),
#  (961, 0.0),
#  (962, 0.15569978883230456),
#  (963, 0.07784989441615231),
#  (964, 0.10011344289651136),
#  (965, 0.0975900072948533),
#  (966, 0.0975900072948533),
#  (967, 0.09128709291752767),
#  (968, 0.09128709291752767),
#  (969, 0.08606629658238701),
#  (970, 0.0778498944161523),
#  (971, 0.1556997888323046),
#  (972, 0.002445937300731203),
#  (973, 0.0),
#  (974, 0.17213259316477403),
#  (975, 0.0816496580927726),
#  (976, 0.07784989441615228),
#  (977, 0.08732790509364546),
#  (978, 0.31459173977130006),
#  (979, 0.0),
#  (980, 0.0),
#  (981, 0.09128709291752768),
#  (982, 0.08606629658238703),
#  (983, 0.0),
#  (984, 0.0),
#  (985, 0.15569978883230462),
#  (986, 0.09128709291752767),
#  (987, 0.0816496580927726),
#  (988, 0.08606629658238704),
#  (989, 0.07161148740394327),
#  (990, 0.05751733544884672),
#  (991, 0.09128709291752767),
#  (992, 0.07453559924999298),
#  (993, 0.07784989441615231),
#  (994, 0.18257418583505533),
#  (995, 0.0),
#  (996, 0.0),
#  (997, 0.0),
#  (998, 0.0),
#  (999, 0.0816496580927726),
#  ...]

# %% [markdown]
# Below are some examples of recommended games. In general, the two versions of recommendations are not critically different and their recommendations are approximately the same. For games that are part of a large franchise, the recommendations may not differ at all (example 2). But the second option, which takes into account the description of the games, may recommend games that are not quite suitable by genre, but suitable by topic.

# %%
# Example 1
naz = "S.T.A.L.K.E.R.: Shadow of Chernobyl"
print('Recommendation for', naz, '\n')
print('Recommendations using game name, developer, genre and tags \n')
print(get_rec(naz, cosine_sim),'\n')
print(print('Recommendations using game name, developer, genre, tags and description \n'))
print(get_rec(naz, cosine_sim2))
# Out:
# Recommendation for S.T.A.L.K.E.R.: Shadow of Chernobyl
#
# Recommendations using game name, developer, genre and tags
#
# 655                       S.T.A.L.K.E.R.: Call of Pripyat
# 378                             S.T.A.L.K.E.R.: Clear Sky
# 410                                             Fallout 3
# 4512                                            Fallout 4
# 415                   Fallout 3: Game of the Year Edition
# 797                                              Gothic 1
# 416                                    Fallout: New Vegas
# 2301                   Hard Truck Apocalypse / Ex Machina
# 1272    Sea Dogs: To Each His Own - Pirate Open World RPG
# 9335                                         Fallout 4 VR
# Name: name, dtype: object
#
# Recommendations using game name, developer, genre, tags and description
#
# None
# 655                       S.T.A.L.K.E.R.: Call of Pripyat
# 378                             S.T.A.L.K.E.R.: Clear Sky
# 410                                             Fallout 3
# 4512                                            Fallout 4
# 415                   Fallout 3: Game of the Year Edition
# 416                                    Fallout: New Vegas
# 2301                   Hard Truck Apocalypse / Ex Machina
# 797                                              Gothic 1
# 1272    Sea Dogs: To Each His Own - Pirate Open World RPG
# 9335                                         Fallout 4 VR
# Name: name, dtype: object

# %%
# Example 2
naz = "Call of Duty® 4: Modern Warfare®"
print('Recommendation for', naz, '\n')
print('Recommendations using game name, developer, genre and tags \n')
print(get_rec(naz, cosine_sim),'\n')
print(print('Recommendations using game name, developer, genre, tags and description \n'))
print(get_rec(naz, cosine_sim2))
# Out:
# Recommendation for Call of Duty® 4: Modern Warfare®
#
# Recommendations using game name, developer, genre and tags
#
# 234              Call of Duty®: Modern Warfare® 2
# 66                                Call of Duty® 2
# 1096                        Call of Duty®: Ghosts
# 4907    Call of Duty®: Modern Warfare® Remastered
# 65                                  Call of Duty®
# 2843                 Call of Duty®: Black Ops III
# 1165        Call of Duty: Black Ops - Mac Edition
# 988                   Call of Duty®: Black Ops II
# 731                                 Borderlands 2
# 5                                        Ricochet
# Name: name, dtype: object
#
# Recommendations using game name, developer, genre, tags and description
#
# None
# 234              Call of Duty®: Modern Warfare® 2
# 66                                Call of Duty® 2
# 1096                        Call of Duty®: Ghosts
# 4907    Call of Duty®: Modern Warfare® Remastered
# 65                                  Call of Duty®
# 2843                 Call of Duty®: Black Ops III
# 1165        Call of Duty: Black Ops - Mac Edition
# 988                   Call of Duty®: Black Ops II
# 731                                 Borderlands 2
# 5                                        Ricochet
# Name: name, dtype: object

# %%
# Example 3
naz = "Tropico 5"
print('Recommendation for', naz, '\n')
print('Recommendations using game name, developer, genre and tags \n')
print(get_rec(naz, cosine_sim),'\n')
print(print('Recommendations using game name, developer, genre, tags and description \n'))
print(get_rec(naz, cosine_sim2))
# Out:
# Recommendation for Tropico 5
#
# Recommendations using game name, developer, genre and tags
#
# 429                         Tropico 3
# 756                         Tropico 4
# 427                  Grand Ages: Rome
# 6594                   Surviving Mars
# 425     Imperium Romanum Gold Edition
# 7615                        Caesar™ 3
# 8776                      Constructor
# 1080       Omerta - City of Gangsters
# 7065                        Tropico 6
# 8481              Pharaoh + Cleopatra
# Name: name, dtype: object
#
# Recommendations using game name, developer, genre, tags and description
#
# None
# 756                         Tropico 4
# 429                         Tropico 3
# 427                  Grand Ages: Rome
# 6594                   Surviving Mars
# 425     Imperium Romanum Gold Edition
# 7615                        Caesar™ 3
# 7065                        Tropico 6
# 539                  Tropico Reloaded
# 8481              Pharaoh + Cleopatra
# 1080       Omerta - City of Gangsters
# Name: name, dtype: object

# %%
# Example 1
naz = "Deathmatch Classic"
print('Recommendation for', naz, '\n')
print('Recommendations using game name, developer, genre and tags \n')
print(get_rec(naz, cosine_sim),'\n')
print(print('Recommendations using game name, developer, genre, tags and description \n'))
print(get_rec(naz, cosine_sim2))
# Out:
# Recommendation for Deathmatch Classic
#
# Recommendations using game name, developer, genre and tags
#
# 1                Team Fortress Classic
# 13             Half-Life 2: Deathmatch
# 5                             Ricochet
# 15        Half-Life Deathmatch: Source
# 0                       Counter-Strike
# 6                            Half-Life
# 10              Counter-Strike: Source
# 7       Counter-Strike: Condition Zero
# 19                     Team Fortress 2
# 3265                        Eradicator
# Name: name, dtype: object
#
# Recommendations using game name, developer, genre, tags and description
#
# None
# 13           Half-Life 2: Deathmatch
# 1              Team Fortress Classic
# 15      Half-Life Deathmatch: Source
# 5                           Ricochet
# 6                          Half-Life
# 0                     Counter-Strike
# 10            Counter-Strike: Source
# 7     Counter-Strike: Condition Zero
# 19                   Team Fortress 2
# 2                      Day of Defeat
# Name: name, dtype: object

# %%
# Example 1
naz = "A Legionary's Life"
print('Recommendation for', naz, '\n')
print('Recommendations using game name, developer, genre and tags \n')
print(get_rec(naz, cosine_sim),'\n')
print(print('Recommendations using game name, developer, genre, tags and description \n'))
print(get_rec(naz, cosine_sim2))
# Out:
# Recommendation for A Legionary's Life
#
# Recommendations using game name, developer, genre and tags
#
# 10148    This Merchant Life
# 7689          LandTraveller
# 11012           Magic Tower
# 11262              Keplerth
# 11312                Egress
# 13598              NEOVERSE
# 13786                   GoK
# 9661       Hobo: Tough Life
# 2621               Abducted
# 2971          Catacomb Kids
# Name: name, dtype: object
#
# Recommendations using game name, developer, genre, tags and description
#
# None
# 10148    This Merchant Life
# 11262              Keplerth
# 11012           Magic Tower
# 13598              NEOVERSE
# 13786                   GoK
# 7689          LandTraveller
# 11312                Egress
# 9661       Hobo: Tough Life
# 6565             FreeHolder
# 7451         Long Gone Days
# Name: name, dtype: object

# %%
#print("CountVectorizer:",CountVectorizer.__version__)
#print("cosine_similarity:",cosine_similarity.__version__)
#print("TfidfVectorizer:",TfidfVectorizer.__version__)
import scipy
import sklearn
print("hstack:",pd.__version__)
# Out:
# hstack: 1.1.5
